# %%
import pandas as pd

# Lista con las rutas de los archivos
archivos = [
    "../models/r2/3features/reultados.csv",
    "../models/r2/4features/reultados.csv",
    "../models/r2/7features/reultados.csv",
    "../models/r2/8features/reultados.csv",
    "../models/r2/8features_pca5/reultados.csv",
    "../models/r2/8features_pca6/reultados.csv",
    "../models/r2/8features_pca5/reultados.csv",
    "../models/r2/todas_PCA5/reultados.csv",
    "../models/r2/todas_PCA6/reultados.csv",
    "../models/r2/todas_PCA10/reultados.csv"
]

# Loop para leer y mostrar las columnas específicas de cada DataFrame
for archivo in archivos:
    df = pd.read_csv(archivo)
    
    # Seleccionar las columnas necesarias
    df_seleccionado = df[['Model', 'Best_params', 'MAE', 'R-squared']]
    
    display(f"Contenido de {archivo}:",df_seleccionado,"\n" + "-"*50 + "\n")
        
    #     print(f"Contenido de {archivo}:")
    # print(df_seleccionado)
    # print("\n" + "-"*50 + "\n")
# Out:
# 'Contenido de ../models/r2/3features/reultados.csv:'
#                      Model                                        Best_params  \
# 0        Linear Regression  {'classifier': LinearRegression(), 'scaler': S...
# 1  Polynomial Regression_2  {'classifier': LinearRegression(), 'polynomial...
# 2  Polynomial Regression_3  {'classifier': LinearRegression(), 'polynomial...
# 3            Decision Tree  {'classifier__max_depth': 5, 'classifier__min_...
# 4            Random Forest  {'classifier__max_depth': 10, 'classifier__min...
# 5       XGBoost (Pipeline)  {'classifier__colsample_bytree': 0.8, 'classif...
# 6      LightGBM (Pipeline)  {'classifier__colsample_bytree': 0.6, 'classif...
# 7           Neural Network                                                  -
#
#         MAE  R-squared
# 0  0.461006   0.813920
# 1  0.411557   0.834132
# 2  0.411480   0.835129
# 3  0.439788   0.775243
# 4  0.418154   0.799667
# 5  0.421111   0.824559
# 6  0.496765   0.766169
# ...

# %%
import pandas as pd

# Lista con las rutas de los archivos
archivos = [
    "../models/mae/3features/reultados.csv",
    "../models/mae/4features/reultados.csv",
    "../models/mae/5features/reultados.csv",
]

# Loop para leer y mostrar las columnas específicas de cada DataFrame
for archivo in archivos:
    df = pd.read_csv(archivo)
    
    # Seleccionar las columnas necesarias
    df_seleccionado = df[['Model', 'Best_params', 'MAE', 'R-squared']]
    
    display(f"Contenido de {archivo}:",df_seleccionado,"\n" + "-"*50 + "\n")
# Out:
# 'Contenido de ../models/mae/3features/reultados.csv:'
#                      Model                                        Best_params  \
# 0        Linear Regression  {'classifier': LinearRegression(), 'scaler': S...
# 1  Polynomial Regression_2  {'classifier': ElasticNet(), 'classifier__alph...
# 2  Polynomial Regression_3  {'classifier': ElasticNet(), 'classifier__alph...
# 3            Decision Tree  {'classifier__max_depth': 5, 'classifier__min_...
# 4            Random Forest  {'classifier__max_depth': 5, 'classifier__min_...
# 5       XGBoost (Pipeline)  {'classifier__colsample_bytree': 0.8, 'classif...
# 6      LightGBM (Pipeline)  {'classifier__colsample_bytree': 0.6, 'classif...
# 7           Neural Network                                                  -
#
#         MAE  R-squared
# 0  0.461006   0.813920
# 1  0.421791   0.821169
# 2  0.419054   0.830546
# 3  0.439788   0.775243
# 4  0.400956   0.824892
# 5  0.422047   0.823115
# 6  0.477647   0.780789
# ...
